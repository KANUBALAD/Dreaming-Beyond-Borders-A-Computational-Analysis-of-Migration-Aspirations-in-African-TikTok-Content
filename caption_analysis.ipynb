# %%
import  pandas as pd

# %%
tiktok_captions = pd.read_csv('tiktok_videos_detailed_20250917_184050.csv')
tiktok_captions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   hashtag    117 non-null    object
#  1   video_url  117 non-null    object
#  2   username   117 non-null    object
#  3   caption    116 non-null    object
#  4   views      117 non-null    int64
#  5   likes      117 non-null    int64
#  6   shares     117 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 6.5+ KB

# %%
tiktok_captions.head()
# Out:
#          hashtag                                          video_url  \
# 0  ghanauknurses  https://www.tiktok.com/@nursegifty/video/74126...
# 1  ghanauknurses  https://www.tiktok.com/@jenniferlomotey85/vide...
# 2  ghanauknurses  https://www.tiktok.com/@scrip_tmusic__/video/7...
# 3  ghanauknurses  https://www.tiktok.com/@officialadjoagucci/vid...
# 4  ghanauknurses  https://www.tiktok.com/@inspirational_kukupak/...
#
#                 username                                            caption  \
# 0             nursegifty  En route to Central London ❤️🇬🇧 #uk #uktiktok ...
# 1      jenniferlomotey85     #ghanatiktokers🇬🇭🇬🇭🇬🇭 #ghanafuo #ghanatiktok🇬🇭
# 2         scrip_tmusic__  Get you are male nurse #malenurse #ghana #rn #...
# 3     officialadjoagucci           #officialadjoaguccci2017 #urfoinenurse💕💕
# 4  inspirational_kukupak  There are shifts and there are “shits”😆😹🤭 Grat...
#
#     views  likes  shares
# 0    4606    337       1
# 1  340900  25300     257
# ...

# %%
tiktok_captions[['caption']]
# Out:
#                                                caption
# 0    En route to Central London ❤️🇬🇧 #uk #uktiktok ...
# 1       #ghanatiktokers🇬🇭🇬🇭🇬🇭 #ghanafuo #ghanatiktok🇬🇭
# 2    Get you are male nurse #malenurse #ghana #rn #...
# 3             #officialadjoaguccci2017 #urfoinenurse💕💕
# 4    There are shifts and there are “shits”😆😹🤭 Grat...
# ..                                                 ...
# 112      #bbyfrancy2 #GNA#Ghana nurses association 🇬🇧💐
# 113  Song titled: I miss you mama 🥹#tiktoknigeriani...
# 114  #LIVEhighlights #TikTokLIVE #LIVE #uknurses🇬🇧 ...
# 115  100 p grocery pack; shipping included. #afrako...
# 116  Ghana Nurses Organization is giving an opportu...
#
# [117 rows x 1 columns]
